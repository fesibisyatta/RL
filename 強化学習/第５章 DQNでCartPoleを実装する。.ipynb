# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
from JSAnimation.IPython_display import display_animation
from matplotlib import animation
from IPython.display import display

# %%
def display_frames_as_gif(frames):
    plt.figure(figsize=(frames[0].shape[1]/ 72.0, frames[0].shape[0]/72.0), dpi=72)
    patch = plt.imshow(frames[0])
    plt.axis('off')
    
    def animate(i):
        patch.set_data(frames[i])
        
    anim = animation.FuncAnimation(plt.gcf(), animate, frames=len(frames), interval=50)
    anim.save('movie_cartpole_DQN.mp4')
    display(display_animation(anim, default_mode='loop'))

from collections import namedtuple
Tr = namedtuple('tr', ('name_a', 'value_b'))
Tr_object = Tr('名前Aです', 100)

print(Tr_object)
print(Tr_object.value_b)
# Out:
# tr(name_a='名前Aです', value_b=100)
# 100

# %%
from collections import namedtuple
Transition = namedtuple('Transition', ('state', 'action', 'next_state', 'reward'))

# %%
ENV = 'CartPole-v0'
GAMMA = 0.9999
MAX_STEPS = 10
NUM_EPISODES = 20

# %%
class ReplayMemory:
    def __init__(self, CAPCITY):
        self.capacity = CAPACITY
        self.memory = memory
        self.index = 0
    
    def push(self, state, action, state_next, reward):
        if len(self.memory) < self.capacity:
            self.memory.append(None)
        self.memory[self.index] = Transition(state, action, state_next, reward)
        self.index = (self.index + 1) % self.capacity
    
    def sample(self, batch_size):
        return random.sample(self.memory, batch_size)
    
    def __len__(self):
        return len(self.memory)

# %%
import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000

# %%
class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # CartPoleの行動（右に左に押す）の2を取得

        # 経験を記憶するメモリオブジェクトを生成
        self.memory = ReplayMemory(CAPACITY)
        
        # ニューラルネットワークを構築
        self.model = nn.Sequential()
        self.model.add_module('fc1', nn.Linear(num_states, 32))
        self.model.add_module('relu1', nn.ReLU())
        self.model.add_module('fc2', nn.Linear(32, 32))
        self.model.add_module('relu2', nn.ReLU())
        self.model.add_module('fc3', nn.Linear(32, num_actions))
        
        print(self.model)  # ネットワークの形を出力
        
        # 最適化手法の設定
        self.optimizer = optim.Adam(self.model.parameters(), lr=0.0001)

    def replay(self):
        '''Experience Replayでネットワークの結合パラメータを学習'''

        # -----------------------------------------
        # 1. メモリサイズの確認
        # -----------------------------------------
        # 1.1 メモリサイズがミニバッチより小さい間は何もしない
        if len(self.memory) < BATCH_SIZE:
            return

        # -----------------------------------------
        # 2. ミニバッチの作成
        # -----------------------------------------
        # 2.1 メモリからミニバッチ分のデータを取り出す
        transitions = self.memory.sample(BATCH_SIZE)

        # 2.2 各変数をミニバッチに対応する形に変形
        # transitionsは1stepごとの(state, action, state_next, reward)が、BATCH_SIZE分格納されている
        # つまり、(state, action, state_next, reward)×BATCH_SIZE
        # これをミニバッチにしたい。つまり
        # (state×BATCH_SIZE, action×BATCH_SIZE, state_next×BATCH_SIZE, reward×BATCH_SIZE)にする
        batch = Transition(*zip(*transitions))

        # 2.3 各変数の要素をミニバッチに対応する形に変形し、ネットワークで扱えるようVariableにする
        # 例えばstateの場合、[torch.FloatTensor of size 1x4]がBATCH_SIZE分並んでいるのですが、
        # それを torch.FloatTensor of size BATCH_SIZEx4 に変換します
        # 状態、行動、報酬、non_finalの状態のミニバッチのVariableを作成
        # catはConcatenates（結合）のことです。
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])

        # -----------------------------------------
        # 3. 教師信号となるQ(s_t, a_t)値を求める
        # -----------------------------------------
        # 3.1 ネットワークを推論モードに切り替える
        self.model.eval()

        # 3.2 ネットワークが出力したQ(s_t, a_t)を求める
        # self.model(state_batch)は、右左の両方のQ値を出力しており
        # [torch.FloatTensor of size BATCH_SIZEx2]になっている。
        # ここから実行したアクションa_tに対応するQ値を求めるため、action_batchで行った行動a_tが右か左かのindexを求め
        # それに対応するQ値をgatherでひっぱり出す。
        state_action_values = self.model(state_batch).gather(1, action_batch)

        # 3.3 max{Q(s_t+1, a)}値を求める。ただし次の状態があるかに注意。

        # cartpoleがdoneになっておらず、next_stateがあるかをチェックするインデックスマスクを作成
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None,
                                                    batch.next_state)))
        # まずは全部0にしておく
        next_state_values = torch.zeros(BATCH_SIZE)

        # 次の状態があるindexの最大Q値を求める
        # 出力にアクセスし、max(1)で列方向の最大値の[値、index]を求めます
        # そしてそのQ値（index=0）を出力します
        # detachでその値を取り出します
        next_state_values[non_final_mask] = self.model(
            non_final_next_states).max(1)[0].detach()

        # 3.4 教師となるQ(s_t, a_t)値を、Q学習の式から求める
        expected_state_action_values = reward_batch + GAMMA * next_state_values

        # -----------------------------------------
        # 4. 結合パラメータの更新
        # -----------------------------------------
        # 4.1 ネットワークを訓練モードに切り替える
        self.model.train()

        # 4.2 損失関数を計算する（smooth_l1_lossはHuberloss）
        # expected_state_action_valuesは
        # sizeが[minbatch]になっているので、unsqueezeで[minibatch x 1]へ
        loss = F.smooth_l1_loss(state_action_values,
                                expected_state_action_values.unsqueeze(1))

        # 4.3 結合パラメータを更新する
        self.optimizer.zero_grad()  # 勾配をリセット
        loss.backward()  # バックプロパゲーションを計算
        self.optimizer.step()  # 結合パラメータを更新

    def decide_action(self, state, episode):
        '''現在の状態に応じて、行動を決定する'''
        # ε-greedy法で徐々に最適行動のみを採用する
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.model.eval()  # ネットワークを推論モードに切り替える
            with torch.no_grad():
                action = self.model(state).max(1)[1].view(1, 1)
            # ネットワークの出力の最大値のindexを取り出します = max(1)[1]
            # .view(1,1)は[torch.LongTensor of size 1]　を size 1x1 に変換します

        else:
            # 0,1の行動をランダムに返す
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  # 0,1の行動をランダムに返す
            # actionは[torch.LongTensor of size 1x1]の形になります

        return action

# %%
class Agent:
    def __init__(self, num_states, num_actions):
        self.brain = Brain(num_states, num_actions)
    def update_q_function(self):
        self.brain.replay()
    def get_action(self, state, episode):
        action = self.brain.decide_action(state, episode)
        return action
    def memorize(self, state, action, state_next, reward):
        self.brain.memory.push(state, action, state_next, reward)

# %%
# CartPoleを実行する環境のクラスです


class Environment:

    def __init__(self):
        self.env = gym.make(ENV)  # 実行する課題を設定
        num_states = self.env.observation_space.shape[0]  # 課題の状態数4を取得
        num_actions = self.env.action_space.n  # CartPoleの行動（右に左に押す）の2を取得
        self.agent = Agent(num_states, num_actions)  # 環境内で行動するAgentを生成

        
    def run(self):
        '''実行'''
        episode_10_list = np.zeros(10)  # 10試行分の立ち続けたstep数を格納し、平均ステップ数を出力に利用
        complete_episodes = 0  # 195step以上連続で立ち続けた試行数
        episode_final = False  # 最後の試行フラグ
        frames = []  # 最後の試行を動画にするために画像を格納する変数

        for episode in range(NUM_EPISODES):  # 最大試行数分繰り返す
            observation = self.env.reset()  # 環境の初期化

            state = observation  # 観測をそのまま状態sとして使用
            state = torch.from_numpy(state).type(
                torch.FloatTensor)  # NumPy変数をPyTorchのテンソルに変換
            state = torch.unsqueeze(state, 0)  # size 4をsize 1x4に変換

            for step in range(MAX_STEPS):  # 1エピソードのループ

                if episode_final is True:  # 最終試行ではframesに各時刻の画像を追加していく
                    frames.append(self.env.render(mode='rgb_array'))

                action = self.agent.get_action(state, episode)  # 行動を求める

                # 行動a_tの実行により、s_{t+1}とdoneフラグを求める
                # actionから.item()を指定して、中身を取り出す
                observation_next, _, done, _ = self.env.step(
                    action.item())  # rewardとinfoは使わないので_にする

                # 報酬を与える。さらにepisodeの終了評価と、state_nextを設定する
                if done:  # ステップ数が200経過するか、一定角度以上傾くとdoneはtrueになる
                    state_next = None  # 次の状態はないので、Noneを格納

                    # 直近10episodeの立てたstep数リストに追加
                    episode_10_list = np.hstack(
                        (episode_10_list[1:], step + 1))

                    if step < 195:
                        reward = torch.FloatTensor(
                            [-1.0])  # 途中でこけたら罰則として報酬-1を与える
                        complete_episodes = 0  # 連続成功記録をリセット
                    else:
                        reward = torch.FloatTensor([1.0])  # 立ったまま終了時は報酬1を与える
                        complete_episodes = complete_episodes + 1  # 連続記録を更新
                else:
                    reward = torch.FloatTensor([0.0])  # 普段は報酬0
                    state_next = observation_next  # 観測をそのまま状態とする
                    state_next = torch.from_numpy(state_next).type(
                        torch.FloatTensor)  # numpy変数をPyTorchのテンソルに変換
                    state_next = torch.unsqueeze(state_next, 0)  # size 4をsize 1x4に変換

                # メモリに経験を追加
                self.agent.memorize(state, action, state_next, reward)

                # Experience ReplayでQ関数を更新する
                self.agent.update_q_function()

                # 観測の更新
                state = state_next

                # 終了時の処理
                if done:
                    print('%d Episode: Finished after %d steps：10試行の平均step数 = %.1lf' % (
                        episode, step + 1, episode_10_list.mean()))
                    break

            if episode_final is True:
                # 動画を保存と描画
                display_frames_as_gif(frames)
                break

            # 10連続で200step経ち続けたら成功
            if complete_episodes >= 10:
                print('10回連続成功')
                episode_final = True  # 次の試行を描画を行う最終試行とする

# %%
cartpole_env = Environment()
cartpole_env.run()
# Out:
# Sequential(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (relu1): ReLU()
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (relu2): ReLU()
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )
# 0 Episode: Finished after 14 steps：10試行の平均step数 = 1.4
# 1 Episode: Finished after 11 steps：10試行の平均step数 = 2.5
# 2 Episode: Finished after 10 steps：10試行の平均step数 = 3.5
# 3 Episode: Finished after 11 steps：10試行の平均step数 = 4.6
# 4 Episode: Finished after 9 steps：10試行の平均step数 = 5.5
# 5 Episode: Finished after 12 steps：10試行の平均step数 = 6.7
# 6 Episode: Finished after 11 steps：10試行の平均step数 = 7.8
# 7 Episode: Finished after 13 steps：10試行の平均step数 = 9.1
# 8 Episode: Finished after 11 steps：10試行の平均step数 = 10.2
# 9 Episode: Finished after 9 steps：10試行の平均step数 = 11.1
# 10 Episode: Finished after 10 steps：10試行の平均step数 = 10.7
# 11 Episode: Finished after 11 steps：10試行の平均step数 = 10.7
# 12 Episode: Finished after 11 steps：10試行の平均step数 = 10.8
# 13 Episode: Finished after 10 steps：10試行の平均step数 = 10.7
# 14 Episode: Finished after 10 steps：10試行の平均step数 = 10.8
# 15 Episode: Finished after 8 steps：10試行の平均step数 = 10.4
# 16 Episode: Finished after 12 steps：10試行の平均step数 = 10.5
# 17 Episode: Finished after 11 steps：10試行の平均step数 = 10.3
# 18 Episode: Finished after 12 steps：10試行の平均step数 = 10.4
# 19 Episode: Finished after 11 steps：10試行の平均step数 = 10.6
# 20 Episode: Finished after 10 steps：10試行の平均step数 = 10.6
# 21 Episode: Finished after 11 steps：10試行の平均step数 = 10.6
# 22 Episode: Finished after 11 steps：10試行の平均step数 = 10.6
# 23 Episode: Finished after 13 steps：10試行の平均step数 = 10.9
# 24 Episode: Finished after 11 steps：10試行の平均step数 = 11.0
# 25 Episode: Finished after 10 steps：10試行の平均step数 = 11.2
# 26 Episode: Finished after 10 steps：10試行の平均step数 = 11.0
# 27 Episode: Finished after 9 steps：10試行の平均step数 = 10.8
# 28 Episode: Finished after 10 steps：10試行の平均step数 = 10.6
# 29 Episode: Finished after 9 steps：10試行の平均step数 = 10.4
# 30 Episode: Finished after 9 steps：10試行の平均step数 = 10.3
# 31 Episode: Finished after 9 steps：10試行の平均step数 = 10.1
# 32 Episode: Finished after 8 steps：10試行の平均step数 = 9.8
# 33 Episode: Finished after 9 steps：10試行の平均step数 = 9.4
# 34 Episode: Finished after 8 steps：10試行の平均step数 = 9.1
# 35 Episode: Finished after 10 steps：10試行の平均step数 = 9.1
# 36 Episode: Finished after 8 steps：10試行の平均step数 = 8.9
# 37 Episode: Finished after 12 steps：10試行の平均step数 = 9.2
# 38 Episode: Finished after 9 steps：10試行の平均step数 = 9.1
# 39 Episode: Finished after 9 steps：10試行の平均step数 = 9.1
# 40 Episode: Finished after 9 steps：10試行の平均step数 = 9.1
# 41 Episode: Finished after 11 steps：10試行の平均step数 = 9.3
# 42 Episode: Finished after 9 steps：10試行の平均step数 = 9.4
# 43 Episode: Finished after 11 steps：10試行の平均step数 = 9.6
# 44 Episode: Finished after 8 steps：10試行の平均step数 = 9.6
# 45 Episode: Finished after 11 steps：10試行の平均step数 = 9.7
# 46 Episode: Finished after 15 steps：10試行の平均step数 = 10.4
# 47 Episode: Finished after 13 steps：10試行の平均step数 = 10.5
# 48 Episode: Finished after 17 steps：10試行の平均step数 = 11.3
# 49 Episode: Finished after 16 steps：10試行の平均step数 = 12.0
# 50 Episode: Finished after 15 steps：10試行の平均step数 = 12.6
# 51 Episode: Finished after 20 steps：10試行の平均step数 = 13.5
# 52 Episode: Finished after 24 steps：10試行の平均step数 = 15.0
# 53 Episode: Finished after 36 steps：10試行の平均step数 = 17.5
# 54 Episode: Finished after 20 steps：10試行の平均step数 = 18.7
# 55 Episode: Finished after 23 steps：10試行の平均step数 = 19.9
# 56 Episode: Finished after 29 steps：10試行の平均step数 = 21.3
# 57 Episode: Finished after 22 steps：10試行の平均step数 = 22.2
# 58 Episode: Finished after 22 steps：10試行の平均step数 = 22.7
# 59 Episode: Finished after 26 steps：10試行の平均step数 = 23.7
# 60 Episode: Finished after 27 steps：10試行の平均step数 = 24.9
# 61 Episode: Finished after 22 steps：10試行の平均step数 = 25.1
# 62 Episode: Finished after 18 steps：10試行の平均step数 = 24.5
# 63 Episode: Finished after 24 steps：10試行の平均step数 = 23.3
# 64 Episode: Finished after 30 steps：10試行の平均step数 = 24.3
# 65 Episode: Finished after 23 steps：10試行の平均step数 = 24.3
# 66 Episode: Finished after 24 steps：10試行の平均step数 = 23.8
# 67 Episode: Finished after 34 steps：10試行の平均step数 = 25.0
# 68 Episode: Finished after 25 steps：10試行の平均step数 = 25.3
# 69 Episode: Finished after 37 steps：10試行の平均step数 = 26.4
# 70 Episode: Finished after 26 steps：10試行の平均step数 = 26.3
# 71 Episode: Finished after 33 steps：10試行の平均step数 = 27.4
# 72 Episode: Finished after 50 steps：10試行の平均step数 = 30.6
# 73 Episode: Finished after 32 steps：10試行の平均step数 = 31.4
# 74 Episode: Finished after 27 steps：10試行の平均step数 = 31.1
# 75 Episode: Finished after 37 steps：10試行の平均step数 = 32.5
# 76 Episode: Finished after 31 steps：10試行の平均step数 = 33.2
# 77 Episode: Finished after 27 steps：10試行の平均step数 = 32.5
# 78 Episode: Finished after 30 steps：10試行の平均step数 = 33.0
# 79 Episode: Finished after 38 steps：10試行の平均step数 = 33.1
# 80 Episode: Finished after 33 steps：10試行の平均step数 = 33.8
# 81 Episode: Finished after 38 steps：10試行の平均step数 = 34.3
# 82 Episode: Finished after 39 steps：10試行の平均step数 = 33.2
# 83 Episode: Finished after 33 steps：10試行の平均step数 = 33.3
# 84 Episode: Finished after 28 steps：10試行の平均step数 = 33.4
# 85 Episode: Finished after 48 steps：10試行の平均step数 = 34.5
# 86 Episode: Finished after 28 steps：10試行の平均step数 = 34.2
# 87 Episode: Finished after 38 steps：10試行の平均step数 = 35.3
# 88 Episode: Finished after 27 steps：10試行の平均step数 = 35.0
# 89 Episode: Finished after 27 steps：10試行の平均step数 = 33.9
# 90 Episode: Finished after 46 steps：10試行の平均step数 = 35.2
# 91 Episode: Finished after 38 steps：10試行の平均step数 = 35.2
# 92 Episode: Finished after 44 steps：10試行の平均step数 = 35.7
# 93 Episode: Finished after 24 steps：10試行の平均step数 = 34.8
# 94 Episode: Finished after 44 steps：10試行の平均step数 = 36.4
# 95 Episode: Finished after 27 steps：10試行の平均step数 = 34.3
# 96 Episode: Finished after 36 steps：10試行の平均step数 = 35.1
# 97 Episode: Finished after 28 steps：10試行の平均step数 = 34.1
# 98 Episode: Finished after 46 steps：10試行の平均step数 = 36.0
# 99 Episode: Finished after 26 steps：10試行の平均step数 = 35.9
# 100 Episode: Finished after 40 steps：10試行の平均step数 = 35.3
# 101 Episode: Finished after 39 steps：10試行の平均step数 = 35.4
# 102 Episode: Finished after 41 steps：10試行の平均step数 = 35.1
# 103 Episode: Finished after 39 steps：10試行の平均step数 = 36.6
# 104 Episode: Finished after 31 steps：10試行の平均step数 = 35.3
# 105 Episode: Finished after 34 steps：10試行の平均step数 = 36.0
# 106 Episode: Finished after 35 steps：10試行の平均step数 = 35.9
# 107 Episode: Finished after 28 steps：10試行の平均step数 = 35.9
# 108 Episode: Finished after 23 steps：10試行の平均step数 = 33.6
# 109 Episode: Finished after 36 steps：10試行の平均step数 = 34.6
# 110 Episode: Finished after 24 steps：10試行の平均step数 = 33.0
# 111 Episode: Finished after 29 steps：10試行の平均step数 = 32.0
# 112 Episode: Finished after 42 steps：10試行の平均step数 = 32.1
# 113 Episode: Finished after 43 steps：10試行の平均step数 = 32.5
# 114 Episode: Finished after 44 steps：10試行の平均step数 = 33.8
# 115 Episode: Finished after 41 steps：10試行の平均step数 = 34.5
# 116 Episode: Finished after 39 steps：10試行の平均step数 = 34.9
# 117 Episode: Finished after 36 steps：10試行の平均step数 = 35.7
# 118 Episode: Finished after 41 steps：10試行の平均step数 = 37.5
# 119 Episode: Finished after 43 steps：10試行の平均step数 = 38.2
# 120 Episode: Finished after 45 steps：10試行の平均step数 = 40.3
# 121 Episode: Finished after 25 steps：10試行の平均step数 = 39.9
# 122 Episode: Finished after 39 steps：10試行の平均step数 = 39.6
# 123 Episode: Finished after 37 steps：10試行の平均step数 = 39.0
# 124 Episode: Finished after 27 steps：10試行の平均step数 = 37.3
# 125 Episode: Finished after 47 steps：10試行の平均step数 = 37.9
# 126 Episode: Finished after 31 steps：10試行の平均step数 = 37.1
# 127 Episode: Finished after 29 steps：10試行の平均step数 = 36.4
# 128 Episode: Finished after 30 steps：10試行の平均step数 = 35.3
# 129 Episode: Finished after 27 steps：10試行の平均step数 = 33.7
# 130 Episode: Finished after 40 steps：10試行の平均step数 = 33.2
# 131 Episode: Finished after 43 steps：10試行の平均step数 = 35.0
# 132 Episode: Finished after 29 steps：10試行の平均step数 = 34.0
# 133 Episode: Finished after 52 steps：10試行の平均step数 = 35.5
# 134 Episode: Finished after 56 steps：10試行の平均step数 = 38.4
# 135 Episode: Finished after 38 steps：10試行の平均step数 = 37.5
# 136 Episode: Finished after 28 steps：10試行の平均step数 = 37.2
# 137 Episode: Finished after 43 steps：10試行の平均step数 = 38.6
# 138 Episode: Finished after 50 steps：10試行の平均step数 = 40.6
# 139 Episode: Finished after 32 steps：10試行の平均step数 = 41.1
# 140 Episode: Finished after 36 steps：10試行の平均step数 = 40.7
# 141 Episode: Finished after 49 steps：10試行の平均step数 = 41.3
# 142 Episode: Finished after 46 steps：10試行の平均step数 = 43.0
# 143 Episode: Finished after 28 steps：10試行の平均step数 = 40.6
# 144 Episode: Finished after 64 steps：10試行の平均step数 = 41.4
# 145 Episode: Finished after 47 steps：10試行の平均step数 = 42.3
# 146 Episode: Finished after 35 steps：10試行の平均step数 = 43.0
# 147 Episode: Finished after 53 steps：10試行の平均step数 = 44.0
# 148 Episode: Finished after 62 steps：10試行の平均step数 = 45.2
# 149 Episode: Finished after 48 steps：10試行の平均step数 = 46.8
# 150 Episode: Finished after 35 steps：10試行の平均step数 = 46.7
# 151 Episode: Finished after 74 steps：10試行の平均step数 = 49.2
# 152 Episode: Finished after 96 steps：10試行の平均step数 = 54.2
# 153 Episode: Finished after 61 steps：10試行の平均step数 = 57.5
# 154 Episode: Finished after 101 steps：10試行の平均step数 = 61.2
# 155 Episode: Finished after 168 steps：10試行の平均step数 = 73.3
# 156 Episode: Finished after 100 steps：10試行の平均step数 = 79.8
# 157 Episode: Finished after 100 steps：10試行の平均step数 = 84.5
# 158 Episode: Finished after 114 steps：10試行の平均step数 = 89.7
# 159 Episode: Finished after 124 steps：10試行の平均step数 = 97.3
# 160 Episode: Finished after 72 steps：10試行の平均step数 = 101.0
# 161 Episode: Finished after 111 steps：10試行の平均step数 = 104.7
# 162 Episode: Finished after 59 steps：10試行の平均step数 = 101.0
# 163 Episode: Finished after 50 steps：10試行の平均step数 = 99.9
# 164 Episode: Finished after 121 steps：10試行の平均step数 = 101.9
# 165 Episode: Finished after 200 steps：10試行の平均step数 = 105.1
# 166 Episode: Finished after 158 steps：10試行の平均step数 = 110.9
# 167 Episode: Finished after 198 steps：10試行の平均step数 = 120.7
# 168 Episode: Finished after 172 steps：10試行の平均step数 = 126.5
# 169 Episode: Finished after 200 steps：10試行の平均step数 = 134.1
# 170 Episode: Finished after 138 steps：10試行の平均step数 = 140.7
# 171 Episode: Finished after 152 steps：10試行の平均step数 = 144.8
# 172 Episode: Finished after 200 steps：10試行の平均step数 = 158.9
# 173 Episode: Finished after 161 steps：10試行の平均step数 = 170.0
# 174 Episode: Finished after 200 steps：10試行の平均step数 = 177.9
# 175 Episode: Finished after 160 steps：10試行の平均step数 = 173.9
# 176 Episode: Finished after 198 steps：10試行の平均step数 = 177.9
# 177 Episode: Finished after 96 steps：10試行の平均step数 = 167.7
# 178 Episode: Finished after 184 steps：10試行の平均step数 = 168.9
# 179 Episode: Finished after 88 steps：10試行の平均step数 = 157.7
# 180 Episode: Finished after 149 steps：10試行の平均step数 = 158.8
# 181 Episode: Finished after 145 steps：10試行の平均step数 = 158.1
# 182 Episode: Finished after 153 steps：10試行の平均step数 = 153.4
# 183 Episode: Finished after 192 steps：10試行の平均step数 = 156.5
# 184 Episode: Finished after 156 steps：10試行の平均step数 = 152.1
# 185 Episode: Finished after 185 steps：10試行の平均step数 = 154.6
# 186 Episode: Finished after 152 steps：10試行の平均step数 = 150.0
# 187 Episode: Finished after 200 steps：10試行の平均step数 = 160.4
# 188 Episode: Finished after 200 steps：10試行の平均step数 = 162.0
# 189 Episode: Finished after 159 steps：10試行の平均step数 = 169.1
# 190 Episode: Finished after 175 steps：10試行の平均step数 = 171.7
# 191 Episode: Finished after 182 steps：10試行の平均step数 = 175.4
# 192 Episode: Finished after 174 steps：10試行の平均step数 = 177.5
# 193 Episode: Finished after 180 steps：10試行の平均step数 = 176.3
# 194 Episode: Finished after 161 steps：10試行の平均step数 = 176.8
# 195 Episode: Finished after 200 steps：10試行の平均step数 = 178.3
# 196 Episode: Finished after 200 steps：10試行の平均step数 = 183.1
# 197 Episode: Finished after 177 steps：10試行の平均step数 = 180.8
# 198 Episode: Finished after 183 steps：10試行の平均step数 = 179.1
# 199 Episode: Finished after 200 steps：10試行の平均step数 = 183.2
# 200 Episode: Finished after 200 steps：10試行の平均step数 = 185.7
# 201 Episode: Finished after 200 steps：10試行の平均step数 = 187.5
# 202 Episode: Finished after 179 steps：10試行の平均step数 = 188.0
# 203 Episode: Finished after 200 steps：10試行の平均step数 = 190.0
# 204 Episode: Finished after 200 steps：10試行の平均step数 = 193.9
# 205 Episode: Finished after 200 steps：10試行の平均step数 = 193.9
# 206 Episode: Finished after 200 steps：10試行の平均step数 = 193.9
# 207 Episode: Finished after 180 steps：10試行の平均step数 = 194.2
# 208 Episode: Finished after 192 steps：10試行の平均step数 = 195.1
# 209 Episode: Finished after 200 steps：10試行の平均step数 = 195.1
# 210 Episode: Finished after 200 steps：10試行の平均step数 = 195.1
# 211 Episode: Finished after 200 steps：10試行の平均step数 = 195.1
# 212 Episode: Finished after 183 steps：10試行の平均step数 = 195.5
# 213 Episode: Finished after 184 steps：10試行の平均step数 = 193.9
# 214 Episode: Finished after 176 steps：10試行の平均step数 = 191.5
# 215 Episode: Finished after 185 steps：10試行の平均step数 = 190.0
# 216 Episode: Finished after 200 steps：10試行の平均step数 = 190.0
# 217 Episode: Finished after 200 steps：10試行の平均step数 = 192.0
# 218 Episode: Finished after 188 steps：10試行の平均step数 = 191.6
# 219 Episode: Finished after 185 steps：10試行の平均step数 = 190.1
# 220 Episode: Finished after 200 steps：10試行の平均step数 = 190.1
# 221 Episode: Finished after 68 steps：10試行の平均step数 = 176.9
# 222 Episode: Finished after 200 steps：10試行の平均step数 = 178.6
# 223 Episode: Finished after 200 steps：10試行の平均step数 = 180.2
# 224 Episode: Finished after 200 steps：10試行の平均step数 = 182.6
# 225 Episode: Finished after 190 steps：10試行の平均step数 = 183.1
# 226 Episode: Finished after 84 steps：10試行の平均step数 = 171.5
# 227 Episode: Finished after 200 steps：10試行の平均step数 = 171.5
# 228 Episode: Finished after 200 steps：10試行の平均step数 = 172.7
# 229 Episode: Finished after 183 steps：10試行の平均step数 = 172.5
# 230 Episode: Finished after 180 steps：10試行の平均step数 = 170.5
# 231 Episode: Finished after 46 steps：10試行の平均step数 = 168.3
# 232 Episode: Finished after 199 steps：10試行の平均step数 = 168.2
# 233 Episode: Finished after 186 steps：10試行の平均step数 = 166.8
# 234 Episode: Finished after 200 steps：10試行の平均step数 = 166.8
# 235 Episode: Finished after 185 steps：10試行の平均step数 = 166.3
# 236 Episode: Finished after 200 steps：10試行の平均step数 = 177.9
# 237 Episode: Finished after 71 steps：10試行の平均step数 = 165.0
# 238 Episode: Finished after 200 steps：10試行の平均step数 = 165.0
# 239 Episode: Finished after 200 steps：10試行の平均step数 = 166.7
# 240 Episode: Finished after 71 steps：10試行の平均step数 = 155.8
# 241 Episode: Finished after 200 steps：10試行の平均step数 = 171.2
# 242 Episode: Finished after 200 steps：10試行の平均step数 = 171.3
# 243 Episode: Finished after 200 steps：10試行の平均step数 = 172.7
# 244 Episode: Finished after 193 steps：10試行の平均step数 = 172.0
# 245 Episode: Finished after 200 steps：10試行の平均step数 = 173.5
# 246 Episode: Finished after 200 steps：10試行の平均step数 = 173.5
# 247 Episode: Finished after 200 steps：10試行の平均step数 = 186.4
# 248 Episode: Finished after 174 steps：10試行の平均step数 = 183.8
# 249 Episode: Finished after 50 steps：10試行の平均step数 = 168.8
# 250 Episode: Finished after 183 steps：10試行の平均step数 = 180.0
# 251 Episode: Finished after 188 steps：10試行の平均step数 = 178.8
# 252 Episode: Finished after 193 steps：10試行の平均step数 = 178.1
# 253 Episode: Finished after 54 steps：10試行の平均step数 = 163.5
# 254 Episode: Finished after 187 steps：10試行の平均step数 = 162.9
# 255 Episode: Finished after 62 steps：10試行の平均step数 = 149.1
# 256 Episode: Finished after 75 steps：10試行の平均step数 = 136.6
# 257 Episode: Finished after 171 steps：10試行の平均step数 = 133.7
# 258 Episode: Finished after 181 steps：10試行の平均step数 = 134.4
# 259 Episode: Finished after 176 steps：10試行の平均step数 = 147.0
# 260 Episode: Finished after 170 steps：10試行の平均step数 = 145.7
# 261 Episode: Finished after 187 steps：10試行の平均step数 = 145.6
# 262 Episode: Finished after 196 steps：10試行の平均step数 = 145.9
# 263 Episode: Finished after 187 steps：10試行の平均step数 = 159.2
# 264 Episode: Finished after 198 steps：10試行の平均step数 = 160.3
# 265 Episode: Finished after 177 steps：10試行の平均step数 = 171.8
# 266 Episode: Finished after 200 steps：10試行の平均step数 = 184.3
# 267 Episode: Finished after 200 steps：10試行の平均step数 = 187.2
# 268 Episode: Finished after 177 steps：10試行の平均step数 = 186.8
# 269 Episode: Finished after 73 steps：10試行の平均step数 = 176.5
# 270 Episode: Finished after 200 steps：10試行の平均step数 = 179.5
# 271 Episode: Finished after 200 steps：10試行の平均step数 = 180.8
# 272 Episode: Finished after 200 steps：10試行の平均step数 = 181.2
# 273 Episode: Finished after 45 steps：10試行の平均step数 = 167.0
# 274 Episode: Finished after 179 steps：10試行の平均step数 = 165.1
# 275 Episode: Finished after 175 steps：10試行の平均step数 = 164.9
# 276 Episode: Finished after 200 steps：10試行の平均step数 = 164.9
# 277 Episode: Finished after 45 steps：10試行の平均step数 = 149.4
# 278 Episode: Finished after 48 steps：10試行の平均step数 = 136.5
# 279 Episode: Finished after 200 steps：10試行の平均step数 = 149.2
# 280 Episode: Finished after 190 steps：10試行の平均step数 = 148.2
# 281 Episode: Finished after 24 steps：10試行の平均step数 = 130.6
# 282 Episode: Finished after 192 steps：10試行の平均step数 = 129.8
# 283 Episode: Finished after 22 steps：10試行の平均step数 = 127.5
# 284 Episode: Finished after 39 steps：10試行の平均step数 = 113.5
# 285 Episode: Finished after 42 steps：10試行の平均step数 = 100.2
# 286 Episode: Finished after 46 steps：10試行の平均step数 = 84.8
# 287 Episode: Finished after 184 steps：10試行の平均step数 = 98.7
# 288 Episode: Finished after 28 steps：10試行の平均step数 = 96.7
# 289 Episode: Finished after 192 steps：10試行の平均step数 = 95.9
# 290 Episode: Finished after 84 steps：10試行の平均step数 = 85.3
# 291 Episode: Finished after 75 steps：10試行の平均step数 = 90.4
# 292 Episode: Finished after 200 steps：10試行の平均step数 = 91.2
# 293 Episode: Finished after 180 steps：10試行の平均step数 = 107.0
# 294 Episode: Finished after 200 steps：10試行の平均step数 = 123.1
# 295 Episode: Finished after 37 steps：10試行の平均step数 = 122.6
# 296 Episode: Finished after 34 steps：10試行の平均step数 = 121.4
# 297 Episode: Finished after 187 steps：10試行の平均step数 = 121.7
# 298 Episode: Finished after 189 steps：10試行の平均step数 = 137.8
# 299 Episode: Finished after 174 steps：10試行の平均step数 = 136.0
# 300 Episode: Finished after 55 steps：10試行の平均step数 = 133.1
# 301 Episode: Finished after 200 steps：10試行の平均step数 = 145.6
# 302 Episode: Finished after 200 steps：10試行の平均step数 = 145.6
# 303 Episode: Finished after 200 steps：10試行の平均step数 = 147.6
# 304 Episode: Finished after 200 steps：10試行の平均step数 = 147.6
# 305 Episode: Finished after 200 steps：10試行の平均step数 = 163.9
# 306 Episode: Finished after 200 steps：10試行の平均step数 = 180.5
# 307 Episode: Finished after 200 steps：10試行の平均step数 = 181.8
# 308 Episode: Finished after 200 steps：10試行の平均step数 = 182.9
# 309 Episode: Finished after 193 steps：10試行の平均step数 = 184.8
# 310 Episode: Finished after 187 steps：10試行の平均step数 = 198.0
# 311 Episode: Finished after 200 steps：10試行の平均step数 = 198.0
# 312 Episode: Finished after 185 steps：10試行の平均step数 = 196.5
# 313 Episode: Finished after 186 steps：10試行の平均step数 = 195.1
# 314 Episode: Finished after 200 steps：10試行の平均step数 = 195.1
# 315 Episode: Finished after 200 steps：10試行の平均step数 = 195.1
# 316 Episode: Finished after 184 steps：10試行の平均step数 = 193.5
# 317 Episode: Finished after 200 steps：10試行の平均step数 = 193.5
# 318 Episode: Finished after 200 steps：10試行の平均step数 = 193.5
# 319 Episode: Finished after 200 steps：10試行の平均step数 = 194.2
# 320 Episode: Finished after 200 steps：10試行の平均step数 = 195.5
# 321 Episode: Finished after 179 steps：10試行の平均step数 = 193.4
# 322 Episode: Finished after 171 steps：10試行の平均step数 = 192.0
# 323 Episode: Finished after 200 steps：10試行の平均step数 = 193.4
# 324 Episode: Finished after 200 steps：10試行の平均step数 = 193.4
# 325 Episode: Finished after 200 steps：10試行の平均step数 = 193.4
# 326 Episode: Finished after 200 steps：10試行の平均step数 = 195.0
# 327 Episode: Finished after 200 steps：10試行の平均step数 = 195.0
# 328 Episode: Finished after 200 steps：10試行の平均step数 = 195.0
# 329 Episode: Finished after 200 steps：10試行の平均step数 = 195.0
# 330 Episode: Finished after 200 steps：10試行の平均step数 = 195.0
# 331 Episode: Finished after 183 steps：10試行の平均step数 = 195.4
# 332 Episode: Finished after 200 steps：10試行の平均step数 = 198.3
# 333 Episode: Finished after 200 steps：10試行の平均step数 = 198.3
# 334 Episode: Finished after 200 steps：10試行の平均step数 = 198.3
# 335 Episode: Finished after 200 steps：10試行の平均step数 = 198.3
# 336 Episode: Finished after 200 steps：10試行の平均step数 = 198.3
# 337 Episode: Finished after 200 steps：10試行の平均step数 = 198.3
# 338 Episode: Finished after 200 steps：10試行の平均step数 = 198.3
# 339 Episode: Finished after 200 steps：10試行の平均step数 = 198.3
# 340 Episode: Finished after 200 steps：10試行の平均step数 = 198.3
# 341 Episode: Finished after 200 steps：10試行の平均step数 = 200.0
# 10回連続成功
# 342 Episode: Finished after 200 steps：10試行の平均step数 = 200.0
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src = this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_forward();}, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function(){t.anim_step_reverse();}, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_imgSGJOCVIFMRRSAQKY">
#     <br>
#     <input id="_anim_sliderSGJOCVIFMRRSAQKY" type="range" style="width:350px" name="points" min="0" max="1" step="1" value="0" onchange="animSGJOCVIFMRRSAQKY.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="animSGJOCVIFMRRSAQKY.slower()">&#8211;</button>
#     <button onclick="animSGJOCVIFMRRSAQKY.first_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSGJOCVIFMRRSAQKY.previous_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSGJOCVIFMRRSAQKY.reverse_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSGJOCVIFMRRSAQKY.pause_animation()"><img class="anim_icon" src="..."></button>
#     <button onclick="animSGJOCVIFMRRSAQKY.play_animation()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSGJOCVIFMRRSAQKY.next_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSGJOCVIFMRRSAQKY.last_frame()"><img class="anim_icon" src="data:image/png;base64,..."></button>
#     <button onclick="animSGJOCVIFMRRSAQKY.faster()">+</button>
#   <form action="#n" name="_anim_loop_selectSGJOCVIFMRRSAQKY" class="anim_control">
#     <input type="radio" name="state" value="once" > Once </input>
#     <input type="radio" name="state" value="loop" checked> Loop </input>
#     <input type="radio" name="state" value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgSGJOCVIFMRRSAQKY";
#     var slider_id = "_anim_sliderSGJOCVIFMRRSAQKY";
#     var loop_select_id = "_anim_loop_selectSGJOCVIFMRRSAQKY";
#     var frames = new Array(0);
#
#   frames[0] = "data:image/png;base64,..."
#   frames[1] = "data:image/png;base64,..."
#   frames[2] = "data:image/png;base64,..."
#   frames[3] = "data:image/png;base64,..."
#   frames[4] = "data:image/png;base64,..."
#   frames[5] = "data:image/png;base64,..."
#   frames[6] = "data:image/png;base64,..."
#   frames[7] = "data:image/png;base64,..."
#   frames[8] = "data:image/png;base64,..."
#   frames[9] = "data:image/png;base64,..."
#   frames[10] = "data:image/png;base64,..."
#   frames[11] = "data:image/png;base64,..."
#   frames[12] = "data:image/png;base64,..."
#   frames[13] = "data:image/png;base64,..."
#   frames[14] = "data:image/png;base64,..."
#   frames[15] = "data:image/png;base64,..."
#   frames[16] = "data:image/png;base64,..."
#   frames[17] = "data:image/png;base64,..."
#   frames[18] = "data:image/png;base64,..."
#   frames[19] = "data:image/png;base64,..."
#   frames[20] = "data:image/png;base64,..."
#   frames[21] = "data:image/png;base64,..."
#   frames[22] = "data:image/png;base64,..."
#   frames[23] = "data:image/png;base64,..."
#   frames[24] = "data:image/png;base64,..."
#   frames[25] = "data:image/png;base64,..."
#   frames[26] = "data:image/png;base64,..."
#   frames[27] = "data:image/png;base64,..."
#   frames[28] = "data:image/png;base64,..."
#   frames[29] = "data:image/png;base64,..."
#   frames[30] = "data:image/png;base64,..."
#   frames[31] = "data:image/png;base64,..."
#   frames[32] = "data:image/png;base64,..."
#   frames[33] = "data:image/png;base64,..."
#   frames[34] = "data:image/png;base64,..."
#   frames[35] = "data:image/png;base64,..."
#   frames[36] = "data:image/png;base64,..."
#   frames[37] = "data:image/png;base64,..."
#   frames[38] = "data:image/png;base64,..."
#   frames[39] = "data:image/png;base64,..."
#   frames[40] = "data:image/png;base64,..."
#   frames[41] = "data:image/png;base64,..."
#   frames[42] = "data:image/png;base64,..."
#   frames[43] = "data:image/png;base64,..."
#   frames[44] = "data:image/png;base64,..."
#   frames[45] = "data:image/png;base64,..."
#   frames[46] = "data:image/png;base64,..."
#   frames[47] = "data:image/png;base64,..."
#   frames[48] = "data:image/png;base64,..."
#   frames[49] = "data:image/png;base64,..."
#   frames[50] = "data:image/png;base64,..."
#   frames[51] = "data:image/png;base64,..."
#   frames[52] = "data:image/png;base64,..."
#   frames[53] = "data:image/png;base64,..."
#   frames[54] = "data:image/png;base64,..."
#   frames[55] = "data:image/png;base64,..."
#   frames[56] = "data:image/png;base64,..."
#   frames[57] = "data:image/png;base6
