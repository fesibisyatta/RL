# %%
# パッケージのimport
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import gym

# %%
# namedtupleを生成
from collections import namedtuple

Transition = namedtuple(
    'Transition', ('state', 'action', 'next_state', 'reward'))

# %%
BATCH_SIZE = 32
CAPACITY = 10000

num_actions = 2
num_states = 4

# 定数の設定
ENV = 'CartPole-v0'  # 使用する課題名
GAMMA = 0.99  # 時間割引率
MAX_STEPS = 200  # 1試行のstep数
NUM_EPISODES = 500  # 最大試行回数

# %%
# 経験を保存するメモリクラスを定義します
class ReplayMemory:

    def __init__(self, CAPACITY):
        self.capacity = CAPACITY  # メモリの最大長さ
        self.memory = []  # 経験を保存する変数
        self.index = 0  # 保存するindexを示す変数

    def push(self, state, action, state_next, reward):
        '''transition = (state, action, state_next, reward)をメモリに保存する'''

        if len(self.memory) < self.capacity:
            self.memory.append(None)  # メモリが満タンでないときは足す

        # namedtupleのTransitionを使用し、値とフィールド名をペアにして保存します
        self.memory[self.index] = Transition(state, action, state_next, reward)

        self.index = (self.index + 1) % self.capacity  # 保存するindexを1つずらす

    def sample(self, batch_size):
        '''batch_size分だけ、ランダムに保存内容を取り出す'''
        return random.sample(self.memory, batch_size)

    def __len__(self):
        '''関数lenに対して、現在の変数memoryの長さを返す'''
        return len(self.memory)

# %%
# ディープ・ニューラルネットワークの構築
import torch.nn as nn
import torch.nn.functional as F


class Net(nn.Module):

    def __init__(self, n_in, n_mid, n_out):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(n_in, n_mid)
        self.fc2 = nn.Linear(n_mid, n_mid)
        
        #Dueling Network
        self.fc3_adv = nn.Linear(n_mid, n_out)
        self.fc3_v = nn.Linear(n_mid, 1)

    def forward(self, x):
        h1 = F.relu(self.fc1(x))
        h2 = F.relu(self.fc2(h1))
        
        adv = self.fc3_adv(h2)
        val = self.fc3_v(h2).expand(-1, adv.size(1))
        
        output = val + adv 
        #- adv.mean(1, keepdim=True).expand(-1, adv.size(1))
        
        return output

# %%
# エージェントが持つ脳となるクラスです、DDQNを実行します

import random
import torch
from torch import nn
from torch import optim
import torch.nn.functional as F

BATCH_SIZE = 32
CAPACITY = 10000


class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions  # CartPoleの行動（右に左に押す）の2を取得

        # 経験を記憶するメモリオブジェクトを生成
        self.memory = ReplayMemory(CAPACITY)

        # ニューラルネットワークを構築
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)  # Netクラスを使用
        self.target_q_network = Net(n_in, n_mid, n_out)  # Netクラスを使用
        print(self.main_q_network)  # ネットワークの形を出力

        # 最適化手法の設定
        self.optimizer = optim.Adam(
            self.main_q_network.parameters(), lr=0.0001)

    def replay(self):
        '''Experience Replayでネットワークの結合パラメータを学習'''

        # 1. メモリサイズの確認
        if len(self.memory) < BATCH_SIZE:
            return

        # 2. ミニバッチの作成
        self.batch, self.state_batch, self.action_batch, self.reward_batch, self.non_final_next_states = self.make_minibatch()

        # 3. 教師信号となるQ(s_t, a_t)値を求める
        self.expected_state_action_values = self.get_expected_state_action_values()

        # 4. 結合パラメータの更新
        self.update_main_q_network()

    def decide_action(self, state, episode):
        '''現在の状態に応じて、行動を決定する'''
        # ε-greedy法で徐々に最適行動のみを採用する
        epsilon = 0.5 * (1 / (episode + 1))

        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval()  # ネットワークを推論モードに切り替える
            with torch.no_grad():
                action = self.main_q_network(state).max(1)[1].view(1, 1)
            # ネットワークの出力の最大値のindexを取り出します = max(1)[1]
            # .view(1,1)は[torch.LongTensor of size 1]　を size 1x1 に変換します

        else:
            # 0,1の行動をランダムに返す
            action = torch.LongTensor(
                [[random.randrange(self.num_actions)]])  # 0,1の行動をランダムに返す
            # actionは[torch.LongTensor of size 1x1]の形になります

        return action

    def make_minibatch(self):
        '''2. ミニバッチの作成'''

        # 2.1 メモリからミニバッチ分のデータを取り出す
        transitions = self.memory.sample(BATCH_SIZE)

        # 2.2 各変数をミニバッチに対応する形に変形
        # transitionsは1stepごとの(state, action, state_next, reward)が、BATCH_SIZE分格納されている
        # つまり、(state, action, state_next, reward)×BATCH_SIZE
        # これをミニバッチにしたい。つまり
        # (state×BATCH_SIZE, action×BATCH_SIZE, state_next×BATCH_SIZE, reward×BATCH_SIZE)にする
        batch = Transition(*zip(*transitions))

        # 2.3 各変数の要素をミニバッチに対応する形に変形し、ネットワークで扱えるようVariableにする
        # 例えばstateの場合、[torch.FloatTensor of size 1x4]がBATCH_SIZE分並んでいるのですが、
        # それを torch.FloatTensor of size BATCH_SIZEx4 に変換します
        # 状態、行動、報酬、non_finalの状態のミニバッチのVariableを作成
        # catはConcatenates（結合）のことです。
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state
                                           if s is not None])

        return batch, state_batch, action_batch, reward_batch, non_final_next_states

    def get_expected_state_action_values(self):
        '''3. 教師信号となるQ(s_t, a_t)値を求める'''

        # 3.1 ネットワークを推論モードに切り替える
        self.main_q_network.eval()
        self.target_q_network.eval()

        # 3.2 ネットワークが出力したQ(s_t, a_t)を求める
        # self.model(state_batch)は、右左の両方のQ値を出力しており
        # [torch.FloatTensor of size BATCH_SIZEx2]になっている。
        # ここから実行したアクションa_tに対応するQ値を求めるため、action_batchで行った行動a_tが右か左かのindexを求め
        # それに対応するQ値をgatherでひっぱり出す。
        self.state_action_values = self.main_q_network(
            self.state_batch).gather(1, self.action_batch)

        # 3.3 max{Q(s_t+1, a)}値を求める。ただし次の状態があるかに注意。

        # cartpoleがdoneになっておらず、next_stateがあるかをチェックするインデックスマスクを作成
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None,
                                                    self.batch.next_state)))
        # まずは全部0にしておく
        next_state_values = torch.zeros(BATCH_SIZE)

        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)

        # 次の状態での最大Q値の行動a_mをMain Q-Networkから求める
        # 最後の[1]で行動に対応したindexが返る
        a_m[non_final_mask] = self.main_q_network(
            self.non_final_next_states).detach().max(1)[1]

        # 次の状態があるものだけにフィルターし、size 32を32×1へ
        a_m_non_final_next_states = a_m[non_final_mask].view(-1, 1)

        # 次の状態があるindexの、行動a_mのQ値をtarget Q-Networkから求める
        # detach()で取り出す
        # squeeze()でsize[minibatch×1]を[minibatch]に。
        next_state_values[non_final_mask] = self.target_q_network(
            self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()

        # 3.4 教師となるQ(s_t, a_t)値を、Q学習の式から求める
        expected_state_action_values = self.reward_batch + GAMMA * next_state_values

        return expected_state_action_values

    def update_main_q_network(self):
        '''4. 結合パラメータの更新'''

        # 4.1 ネットワークを訓練モードに切り替える
        self.main_q_network.train()

        # 4.2 損失関数を計算する（smooth_l1_lossはHuberloss）
        # expected_state_action_valuesは
        # sizeが[minbatch]になっているので、unsqueezeで[minibatch x 1]へ
        loss = F.smooth_l1_loss(self.state_action_values,
                                self.expected_state_action_values.unsqueeze(1))

        # 4.3 結合パラメータを更新する
        self.optimizer.zero_grad()  # 勾配をリセット
        loss.backward()  # バックプロパゲーションを計算
        self.optimizer.step()  # 結合パラメータを更新

    def update_target_q_network(self):  # DDQNで追加
        '''Target Q-NetworkをMainと同じにする'''
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())

# %%
'''
class Brain:
    def __init__(self, num_states, num_actions):
        self.num_actions = num_actions
        self.memory = ReplayMemory(CAPACITY)
        
        n_in, n_mid, n_out = num_states, 32, num_actions
        self.main_q_network = Net(n_in, n_mid, n_out)
        self.target_q_network = Net(n_in, n_mid, n_out)
        print(self.main_q_network)
        
        self.optimizer = optim.Adam(self.main_q_network.parameters(), lr=0.0001)
        
    def replay(self):
        #メモリサイズを確認し、BATCH_SIZEよりも小さければ何も返さない.
        if len(self.memory) < BATCH_SIZE:
            return 
        
        #ミニバッチを作成する
        self.batch, self.state_batch, self.action_batch, self.reward_batch,
        self.non_final_next_states = self.make_minibatch()
    
        #教師信号となるQ(s_t, a_t)を求める
        self.expected_state_action_values = self.get_expected_state_action_values()
    
        #mainのネットワークを更新する。
        self.updates_main_q_network()
    
    def decide_action(self, state, episode):
        #ε-greedy法による行動選択
        epsilon = 0.5 * (1 / (episode + 1))
        
        if epsilon <= np.random.uniform(0, 1):
            self.main_q_network.eval()
            with torch.no_grad():
                action = self.main_q_network(state).max(1)[1].view(1, 1)
        
        else:
            action = torch.LongTensor([[random.randrange(self.num_actions)]])
        
        return action
    
    def make_minibatch(self):
        transitions = self.memory.sample(BATCH_SIZE)
        batch = Transition(*zip(*transitions))
        
        state_batch = torch.cat(batch.state)
        action_batch = torch.cat(batch.action)
        reward_batch = torch.cat(batch.reward)
        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])
        
        return batch, state_batch, action_batch, reward_batch, non_final_next_states
    
    def get_expected_state_action_values(self):
        self.main_q_network.eval()
        self.target_q_network.eval()
        
        #右辺はstateをnetに放り込んでいるので、出力がactionになっており、それをランダムサンプリングしたactionで抜き出している。
        self.state_action_values = self.main_q_network(self.state_batch).gather(1, self.action_batch)
        
        # batch.next_stateの各要素にNoneが含まれていれば、その箇所をFalseと入力しtupleで格納して、tensorとして出力する。これがマスクになる。
        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, self.batch.next_state)))
        
        #次の状態を0とする。
        next_state_values = torch.zeros(BATCH_SIZE)
        
        #Long型のtensorに変換する。
        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)
        
        a_m[non_final_mask] = self.main_q_network(self.non_final_next_states).detach().max(1)[1]
        a_m_non_final_next_states = a_m[non_final_mask].view(-1,1)
        
        #target Netで取得したQ値から次の状態がNoneではないものを取得し, squeezeで形を整える。
        next_state_values[non_final_mask] = self.target_q_network(self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()
        
        #期待されるQ値をQ学習の更新式から求める
        expected_state_action_values = self.reward_batch + GAMMA*next_state_values
        return expected_state_action_values
    
    def update_main_q_network(self):
        
        self.main_q_network.train()
        
        #expected_state_action_valuesはサイズが[minibatch]になっているからunsqueezeを用いて[minibatch ✖︎ 1]にする。
        loss = F.smooth_l1_loss(self.state_action_values, self.expected_state_action_values.unsqueeze(1))
        
        #勾配をリセットにする。
        self.optimizer.zero_grad()
        
        #損失を逆伝播で計算する。
        loss.backward()
        
        #結合パラメータを計算する。
        self.optimizer.step()
        
    def update_target_q_network(self):
        self.target_q_network.load_state_dict(self.main_q_network.state_dict())        
'''
# Out:
# '\nclass Brain:\n    def __init__(self, num_states, num_actions):\n        self.num_actions = num_actions\n        self.memory = ReplayMemory(CAPACITY)\n        \n        n_in, n_mid, n_out = num_states, 32, num_actions\n        self.main_q_network = Net(n_in, n_mid, n_out)\n        self.target_q_network = Net(n_in, n_mid, n_out)\n        print(self.main_q_network)\n        \n        self.optimizer = optim.Adam(self.main_q_network.parameters(), lr=0.0001)\n        \n    def replay(self):\n        #メモリサイズを確認し、BATCH_SIZEよりも小さければ何も返さない.\n        if len(self.memory) < BATCH_SIZE:\n            return \n        \n        #ミニバッチを作成する\n        self.batch, self.state_batch, self.action_batch, self.reward_batch,\n        self.non_final_next_states = self.make_minibatch()\n    \n        #教師信号となるQ(s_t, a_t)を求める\n        self.expected_state_action_values = self.get_expected_state_action_values()\n    \n        #mainのネットワークを更新する。\n        self.updates_main_q_network()\n    \n    def decide_action(self, state, episode):\n        #ε-greedy法による行動選択\n        epsilon = 0.5 * (1 / (episode + 1))\n        \n        if epsilon <= np.random.uniform(0, 1):\n            self.main_q_network.eval()\n            with torch.no_grad():\n                action = self.main_q_network(state).max(1)[1].view(1, 1)\n        \n        else:\n            action = torch.LongTensor([[random.randrange(self.num_actions)]])\n        \n        return action\n    \n    def make_minibatch(self):\n        transitions = self.memory.sample(BATCH_SIZE)\n        batch = Transition(*zip(*transitions))\n        \n        state_batch = torch.cat(batch.state)\n        action_batch = torch.cat(batch.action)\n        reward_batch = torch.cat(batch.reward)\n        non_final_next_states = torch.cat([s for s in batch.next_state if s is not None])\n        \n        return batch, state_batch, action_batch, reward_batch, non_final_next_states\n    \n    def get_expected_state_action_values(self):\n        self.main_q_network.eval()\n        self.target_q_network.eval()\n        \n        #右辺はstateをnetに放り込んでいるので、出力がactionになっており、それをランダムサンプリングしたactionで抜き出している。\n        self.state_action_values = self.main_q_network(self.state_batch).gather(1, self.action_batch)\n        \n        # batch.next_stateの各要素にNoneが含まれていれば、その箇所をFalseと入力しtupleで格納して、tensorとして出力する。これがマスクになる。\n        non_final_mask = torch.ByteTensor(tuple(map(lambda s: s is not None, self.batch.next_state)))\n        \n        #次の状態を0とする。\n        next_state_values = torch.zeros(BATCH_SIZE)\n        \n        #Long型のtensorに変換する。\n        a_m = torch.zeros(BATCH_SIZE).type(torch.LongTensor)\n        \n        a_m[non_final_mask] = self.main_q_network(self.non_final_next_states).detach().max(1)[1]\n        a_m_non_final_next_states = a_m[non_final_mask].view(-1,1)\n        \n        #target Netで取得したQ値から次の状態がNoneではないものを取得し, squeezeで形を整える。\n        next_state_values[non_final_mask] = self.target_q_network(self.non_final_next_states).gather(1, a_m_non_final_next_states).detach().squeeze()\n        \n        #期待されるQ値をQ学習の更新式から求める\n        expected_state_action_values = self.reward_batch + GAMMA*next_state_values\n        return expected_state_action_values\n    \n    def update_main_q_network(self):\n        \n        self.main_q_network.train()\n        \n        #expected_state_action_valuesはサイズが[minibatch]になっているからunsqueezeを用いて[minibatch ✖︎ 1]にする。\n        loss = F.smooth_l1_loss(self.state_action_values, self.expected_state_action_values.unsqueeze(1))\n        \n        #勾配をリセットにする。\n        self.optimizer.zero_grad()\n        \n        #損失を逆伝播で計算する。\n        loss.backward()\n        \n        #結合パラメータを計算する。\n        self.optimizer.step()\n        \n    def update_target_q_network(self):\n        self.target_q_network.load_state_dict(self.main_q_network.state_dict())        \n'

# %%
# CartPoleで動くエージェントクラスです、棒付き台車そのものになります


class Agent:
    def __init__(self, num_states, num_actions):
        '''課題の状態と行動の数を設定する'''
        self.brain = Brain(num_states, num_actions)  # エージェントが行動を決定するための頭脳を生成

    def update_q_function(self):
        '''Q関数を更新する'''
        self.brain.replay()

    def get_action(self, state, episode):
        '''行動を決定する'''
        action = self.brain.decide_action(state, episode)
        return action

    def memorize(self, state, action, state_next, reward):
        '''memoryオブジェクトに、state, action, state_next, rewardの内容を保存する'''
        self.brain.memory.push(state, action, state_next, reward)

    def update_target_q_function(self):
        '''Target Q-NetworkをMain Q-Networkと同じに更新'''
        self.brain.update_target_q_network()

# %%
# CartPoleを実行する環境のクラスです


class Environment:

    def __init__(self):
        self.env = gym.make(ENV)  # 実行する課題を設定
        num_states = self.env.observation_space.shape[0]  # 課題の状態と行動の数を設定
        num_actions = self.env.action_space.n  # CartPoleの行動（右に左に押す）の2を取得
        # 環境内で行動するAgentを生成
        self.agent = Agent(num_states, num_actions)

    def run(self):
        '''実行'''
        episode_10_list = np.zeros(10)  # 10試行分の立ち続けたstep数を格納し、平均ステップ数を出力に利用
        complete_episodes = 0  # 195step以上連続で立ち続けた試行数
        episode_final = False  # 最後の試行フラグ
        frames = []  # 最後の試行を動画にするために画像を格納する変数

        for episode in range(NUM_EPISODES):  # 試行数分繰り返す
            observation = self.env.reset()  # 環境の初期化

            state = observation  # 観測をそのまま状態sとして使用
            state = torch.from_numpy(state).type(
                torch.FloatTensor)  # numpy変数をPyTorchのテンソルに変換
            state = torch.unsqueeze(state, 0)  # size 4をsize 1x4に変換

            for step in range(MAX_STEPS):  # 1エピソードのループ
                
                # 動画描画をコメントアウトしています
                #if episode_final is True:  # 最終試行ではframesに各時刻の画像を追加していく
                    # frames.append(self.env.render(mode='rgb_array'))
                    
                action = self.agent.get_action(state, episode)  # 行動を求める

                # 行動a_tの実行により、s_{t+1}とdoneフラグを求める
                # actionから.item()を指定して、中身を取り出す
                observation_next, _, done, _ = self.env.step(
                    action.item())  # rewardとinfoは使わないので_にする

                # 報酬を与える。さらにepisodeの終了評価と、state_nextを設定する
                if done:  # ステップ数が200経過するか、一定角度以上傾くとdoneはtrueになる
                    state_next = None  # 次の状態はないので、Noneを格納

                    # 直近10episodeの立てたstep数リストに追加
                    episode_10_list = np.hstack(
                        (episode_10_list[1:], step + 1))

                    if step < 195:
                        reward = torch.FloatTensor(
                            [-1.0])  # 途中でこけたら罰則として報酬-1を与える
                        complete_episodes = 0  # 連続成功記録をリセット
                    else:
                        reward = torch.FloatTensor([1.0])  # 立ったまま終了時は報酬1を与える
                        complete_episodes = complete_episodes + 1  # 連続記録を更新
                else:
                    reward = torch.FloatTensor([0.0])  # 普段は報酬0
                    state_next = observation_next  # 観測をそのまま状態とする
                    state_next = torch.from_numpy(state_next).type(
                        torch.FloatTensor)  # numpy変数をPyTorchのテンソルに変換
                    state_next = torch.unsqueeze(state_next, 0)  # size 4をsize 1x4に変換

                # メモリに経験を追加
                self.agent.memorize(state, action, state_next, reward)

                # Experience ReplayでQ関数を更新する
                self.agent.update_q_function()

                # 観測の更新
                state = state_next

                # 終了時の処理
                if done:
                    print('%d Episode: Finished after %d steps：10試行の平均step数 = %.1lf' % (
                        episode, step + 1, episode_10_list.mean()))
                    
                    # DDQNで追加、2試行に1度、Target Q-NetworkをMainと同じにコピーする
                    if(episode % 2 == 0):
                        self.agent.update_target_q_function()
                    break
                    
                    
            if episode_final is True:
                # 動画描画をコメントアウトしています
                # 動画を保存と描画
                #display_frames_as_gif(frames)
                break

            # 10連続で200step経ち続けたら成功
            if complete_episodes >= 10:
                print('10回連続成功')
                episode_final = True  # 次の試行を描画を行う最終試行とする

# %%
'''
class Environment:
    def __init__(self):
        self.env = gym.make(ENV)
        
        #self.envにはstate, action, reward, done, next_stateが格納されており、indexが0の時はstateが格納されている。
        num_states = self.env.observation_space.shape[0]
        
        #self.env.action_spaceにはDescrete(2)が格納されており、indexだけ取り出す。つまり出力は2になる。
        num_action = self.env.action_space.n
        
        #環境内で行動するAgentを生成。
        self.agent = Agent(num_states, num_actions)
    
    def run(self):
        
        episode_10_list = np.zeros(10)
        
        #195step以上連続でたち続けた試行数
        complete_episodes = 0
        
        #最後の試行フラグ
        episode_final = False
        
        for episode in range(NUM_EPISODE):
            
            #observationを初期化し、stateへ代入する。
            observation = self.env.reset()
            state = observation #array配列になっている.
            
            #tensorに変換する。
            state = torch.from_numpy(state).type(torch.FloatTensor)
            
            #stateを 4から1× 4に変換する。
            state = torch.unsqueeze(state, 0)
            
            for step in range(MAX_STEPS):
                #現在のepisodeとstateから行動選択をする。
                action = self.agent.get_action(state, episode)
                
                #上で取得したactionを用いて次の状態、報酬、doneを取得する。
                observation_next, _, done, _ = self.env.step(action.item())
                
                if done:
                    state_next = None
                    
                    #直近10episodeの立てたstep数をリストに追加する。
                    episode_10_list = np.hstack(episode_10_list[1:], step + 1)
                    
                    if step < 195:
                        #途中で倒れたら-1を報酬に与える。
                        reward = torch.FloatTensor([-1.0])
                        #連続成功記録を0にする
                        complete_episodes = 0
                    
                    else:
                        #報酬に1.0を加える。
                        reward = torch.FloatTensor([1.0])
                        
                        #今までのエピソード数を更新する。
                        complete_episode = cpmplete_episode + 1
                
                #倒れていない時
                else:
                    reward = torch.FloatTensor([0.0])
                    state_next = observation_next
                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)
                    state_next = torch.unsqueeze(state_next, 0)
                
                #倒れていようがいまいが、メモリに追加する。
                self.agent.memorize(state, action, state_next, reward)
                
                #Experience replayでQ値を更新する。
                self.agent.update_q_function()
                
                #stateの更新
                state = state_next
                
                # 終了時の処理
                if done:
                    print('%d Episode: Finished after %d steps: 10試行の平均step数 = %.1lf' % (episode, step + 1, episode_10_list.mean()))
                    
                    #2回に1回target networkをmain netで更新する。
                    if(episode % 2 == 0):
                        self.agent.update_target_q_function()
                        break
                    
                    if episode_final is True:
                        break
                    
                    if complete_episodes >= 10:
                        print('10回連続成功')
                        episode_final = True
'''
# Out:
# "\nclass Environment:\n    def __init__(self):\n        self.env = gym.make(ENV)\n        \n        #self.envにはstate, action, reward, done, next_stateが格納されており、indexが0の時はstateが格納されている。\n        num_states = self.env.observation_space.shape[0]\n        \n        #self.env.action_spaceにはDescrete(2)が格納されており、indexだけ取り出す。つまり出力は2になる。\n        num_action = self.env.action_space.n\n        \n        #環境内で行動するAgentを生成。\n        self.agent = Agent(num_states, num_actions)\n    \n    def run(self):\n        \n        episode_10_list = np.zeros(10)\n        \n        #195step以上連続でたち続けた試行数\n        complete_episodes = 0\n        \n        #最後の試行フラグ\n        episode_final = False\n        \n        for episode in range(NUM_EPISODE):\n            \n            #observationを初期化し、stateへ代入する。\n            observation = self.env.reset()\n            state = observation #array配列になっている.\n            \n            #tensorに変換する。\n            state = torch.from_numpy(state).type(torch.FloatTensor)\n            \n            #stateを 4から1× 4に変換する。\n            state = torch.unsqueeze(state, 0)\n            \n            for step in range(MAX_STEPS):\n                #現在のepisodeとstateから行動選択をする。\n                action = self.agent.get_action(state, episode)\n                \n                #上で取得したactionを用いて次の状態、報酬、doneを取得する。\n                observation_next, _, done, _ = self.env.step(action.item())\n                \n                if done:\n                    state_next = None\n                    \n                    #直近10episodeの立てたstep数をリストに追加する。\n                    episode_10_list = np.hstack(episode_10_list[1:], step + 1)\n                    \n                    if step < 195:\n                        #途中で倒れたら-1を報酬に与える。\n                        reward = torch.FloatTensor([-1.0])\n                        #連続成功記録を0にする\n                        complete_episodes = 0\n                    \n                    else:\n                        #報酬に1.0を加える。\n                        reward = torch.FloatTensor([1.0])\n                        \n                        #今までのエピソード数を更新する。\n                        complete_episode = cpmplete_episode + 1\n                \n                #倒れていない時\n                else:\n                    reward = torch.FloatTensor([0.0])\n                    state_next = observation_next\n                    state_next = torch.from_numpy(state_next).type(torch.FloatTensor)\n                    state_next = torch.unsqueeze(state_next, 0)\n                \n                #倒れていようがいまいが、メモリに追加する。\n                self.agent.memorize(state, action, state_next, reward)\n                \n                #Experience replayでQ値を更新する。\n                self.agent.update_q_function()\n                \n                #stateの更新\n                state = state_next\n                \n                # 終了時の処理\n                if done:\n                    print('%d Episode: Finished after %d steps: 10試行の平均step数 = %.1lf' % (episode, step + 1, episode_10_list.mean()))\n                    \n                    #2回に1回target networkをmain netで更新する。\n                    if(episode % 2 == 0):\n                        self.agent.update_target_q_function()\n                        break\n                    \n                    if episode_final is True:\n                        break\n                    \n                    if complete_episodes >= 10:\n                        print('10回連続成功')\n                        episode_final = True\n"

# %%
# main クラス
cartpole_env = Environment()
# Out:
# Net(
#   (fc1): Linear(in_features=4, out_features=32, bias=True)
#   (fc2): Linear(in_features=32, out_features=32, bias=True)
#   (fc3_adv): Linear(in_features=32, out_features=2, bias=True)
#   (fc3_v): Linear(in_features=32, out_features=1, bias=True)
# )

# %%
cartpole_env.run()
# Out:
# 0 Episode: Finished after 14 steps：10試行の平均step数 = 1.4
# 1 Episode: Finished after 11 steps：10試行の平均step数 = 2.5
# 2 Episode: Finished after 11 steps：10試行の平均step数 = 3.6
# 3 Episode: Finished after 10 steps：10試行の平均step数 = 4.6
# 4 Episode: Finished after 11 steps：10試行の平均step数 = 5.7
# 5 Episode: Finished after 10 steps：10試行の平均step数 = 6.7
# 6 Episode: Finished after 11 steps：10試行の平均step数 = 7.8
# 7 Episode: Finished after 11 steps：10試行の平均step数 = 8.9
# 8 Episode: Finished after 10 steps：10試行の平均step数 = 9.9
# 9 Episode: Finished after 9 steps：10試行の平均step数 = 10.8
# 10 Episode: Finished after 11 steps：10試行の平均step数 = 10.5
# 11 Episode: Finished after 10 steps：10試行の平均step数 = 10.4
# 12 Episode: Finished after 11 steps：10試行の平均step数 = 10.4
# 13 Episode: Finished after 12 steps：10試行の平均step数 = 10.6
# 14 Episode: Finished after 12 steps：10試行の平均step数 = 10.7
# 15 Episode: Finished after 12 steps：10試行の平均step数 = 10.9
# 16 Episode: Finished after 11 steps：10試行の平均step数 = 10.9
# 17 Episode: Finished after 10 steps：10試行の平均step数 = 10.8
# 18 Episode: Finished after 10 steps：10試行の平均step数 = 10.8
# 19 Episode: Finished after 9 steps：10試行の平均step数 = 10.8
# 20 Episode: Finished after 9 steps：10試行の平均step数 = 10.6
# 21 Episode: Finished after 9 steps：10試行の平均step数 = 10.5
# 22 Episode: Finished after 8 steps：10試行の平均step数 = 10.2
# 23 Episode: Finished after 10 steps：10試行の平均step数 = 10.0
# 24 Episode: Finished after 10 steps：10試行の平均step数 = 9.8
# 25 Episode: Finished after 9 steps：10試行の平均step数 = 9.5
# 26 Episode: Finished after 10 steps：10試行の平均step数 = 9.4
# 27 Episode: Finished after 8 steps：10試行の平均step数 = 9.2
# 28 Episode: Finished after 10 steps：10試行の平均step数 = 9.2
# 29 Episode: Finished after 11 steps：10試行の平均step数 = 9.4
# 30 Episode: Finished after 9 steps：10試行の平均step数 = 9.4
# 31 Episode: Finished after 9 steps：10試行の平均step数 = 9.4
# 32 Episode: Finished after 22 steps：10試行の平均step数 = 10.8
# 33 Episode: Finished after 8 steps：10試行の平均step数 = 10.6
# 34 Episode: Finished after 9 steps：10試行の平均step数 = 10.5
# 35 Episode: Finished after 10 steps：10試行の平均step数 = 10.6
# 36 Episode: Finished after 10 steps：10試行の平均step数 = 10.6
# 37 Episode: Finished after 9 steps：10試行の平均step数 = 10.7
# 38 Episode: Finished after 10 steps：10試行の平均step数 = 10.7
# 39 Episode: Finished after 9 steps：10試行の平均step数 = 10.5
# 40 Episode: Finished after 9 steps：10試行の平均step数 = 10.5
# 41 Episode: Finished after 9 steps：10試行の平均step数 = 10.5
# 42 Episode: Finished after 11 steps：10試行の平均step数 = 9.4
# 43 Episode: Finished after 9 steps：10試行の平均step数 = 9.5
# 44 Episode: Finished after 9 steps：10試行の平均step数 = 9.5
# 45 Episode: Finished after 10 steps：10試行の平均step数 = 9.5
# 46 Episode: Finished after 10 steps：10試行の平均step数 = 9.5
# 47 Episode: Finished after 10 steps：10試行の平均step数 = 9.6
# 48 Episode: Finished after 10 steps：10試行の平均step数 = 9.6
# 49 Episode: Finished after 10 steps：10試行の平均step数 = 9.7
# 50 Episode: Finished after 10 steps：10試行の平均step数 = 9.8
# 51 Episode: Finished after 9 steps：10試行の平均step数 = 9.8
# 52 Episode: Finished after 9 steps：10試行の平均step数 = 9.6
# 53 Episode: Finished after 9 steps：10試行の平均step数 = 9.6
# 54 Episode: Finished after 9 steps：10試行の平均step数 = 9.6
# 55 Episode: Finished after 10 steps：10試行の平均step数 = 9.6
# 56 Episode: Finished after 10 steps：10試行の平均step数 = 9.6
# 57 Episode: Finished after 10 steps：10試行の平均step数 = 9.6
# 58 Episode: Finished after 11 steps：10試行の平均step数 = 9.7
# 59 Episode: Finished after 10 steps：10試行の平均step数 = 9.7
# 60 Episode: Finished after 13 steps：10試行の平均step数 = 10.0
# 61 Episode: Finished after 68 steps：10試行の平均step数 = 15.9
# 62 Episode: Finished after 32 steps：10試行の平均step数 = 18.2
# 63 Episode: Finished after 70 steps：10試行の平均step数 = 24.3
# 64 Episode: Finished after 40 steps：10試行の平均step数 = 27.4
# 65 Episode: Finished after 44 steps：10試行の平均step数 = 30.8
# 66 Episode: Finished after 40 steps：10試行の平均step数 = 33.8
# 67 Episode: Finished after 38 steps：10試行の平均step数 = 36.6
# 68 Episode: Finished after 94 steps：10試行の平均step数 = 44.9
# 69 Episode: Finished after 40 steps：10試行の平均step数 = 47.9
# 70 Episode: Finished after 48 steps：10試行の平均step数 = 51.4
# 71 Episode: Finished after 50 steps：10試行の平均step数 = 49.6
# 72 Episode: Finished after 37 steps：10試行の平均step数 = 50.1
# 73 Episode: Finished after 90 steps：10試行の平均step数 = 52.1
# 74 Episode: Finished after 52 steps：10試行の平均step数 = 53.3
# 75 Episode: Finished after 69 steps：10試行の平均step数 = 55.8
# 76 Episode: Finished after 64 steps：10試行の平均step数 = 58.2
# 77 Episode: Finished after 48 steps：10試行の平均step数 = 59.2
# 78 Episode: Finished after 76 steps：10試行の平均step数 = 57.4
# 79 Episode: Finished after 55 steps：10試行の平均step数 = 58.9
# 80 Episode: Finished after 40 steps：10試行の平均step数 = 58.1
# 81 Episode: Finished after 63 steps：10試行の平均step数 = 59.4
# 82 Episode: Finished after 43 steps：10試行の平均step数 = 60.0
# 83 Episode: Finished after 71 steps：10試行の平均step数 = 58.1
# 84 Episode: Finished after 29 steps：10試行の平均step数 = 55.8
# 85 Episode: Finished after 43 steps：10試行の平均step数 = 53.2
# 86 Episode: Finished after 60 steps：10試行の平均step数 = 52.8
# 87 Episode: Finished after 49 steps：10試行の平均step数 = 52.9
# 88 Episode: Finished after 45 steps：10試行の平均step数 = 49.8
# 89 Episode: Finished after 40 steps：10試行の平均step数 = 48.3
# 90 Episode: Finished after 73 steps：10試行の平均step数 = 51.6
# 91 Episode: Finished after 38 steps：10試行の平均step数 = 49.1
# 92 Episode: Finished after 95 steps：10試行の平均step数 = 54.3
# 93 Episode: Finished after 59 steps：10試行の平均step数 = 53.1
# 94 Episode: Finished after 41 steps：10試行の平均step数 = 54.3
# 95 Episode: Finished after 64 steps：10試行の平均step数 = 56.4
# 96 Episode: Finished after 39 steps：10試行の平均step数 = 54.3
# 97 Episode: Finished after 51 steps：10試行の平均step数 = 54.5
# 98 Episode: Finished after 56 steps：10試行の平均step数 = 55.6
# 99 Episode: Finished after 42 steps：10試行の平均step数 = 55.8
# 100 Episode: Finished after 38 steps：10試行の平均step数 = 52.3
# 101 Episode: Finished after 76 steps：10試行の平均step数 = 56.1
# 102 Episode: Finished after 39 steps：10試行の平均step数 = 50.5
# 103 Episode: Finished after 46 steps：10試行の平均step数 = 49.2
# 104 Episode: Finished after 51 steps：10試行の平均step数 = 50.2
# 105 Episode: Finished after 49 steps：10試行の平均step数 = 48.7
# 106 Episode: Finished after 107 steps：10試行の平均step数 = 55.5
# 107 Episode: Finished after 165 steps：10試行の平均step数 = 66.9
# 108 Episode: Finished after 107 steps：10試行の平均step数 = 72.0
# 109 Episode: Finished after 86 steps：10試行の平均step数 = 76.4
# 110 Episode: Finished after 137 steps：10試行の平均step数 = 86.3
# 111 Episode: Finished after 146 steps：10試行の平均step数 = 93.3
# 112 Episode: Finished after 132 steps：10試行の平均step数 = 102.6
# 113 Episode: Finished after 87 steps：10試行の平均step数 = 106.7
# 114 Episode: Finished after 85 steps：10試行の平均step数 = 110.1
# 115 Episode: Finished after 104 steps：10試行の平均step数 = 115.6
# 116 Episode: Finished after 200 steps：10試行の平均step数 = 124.9
# 117 Episode: Finished after 147 steps：10試行の平均step数 = 123.1
# 118 Episode: Finished after 111 steps：10試行の平均step数 = 123.5
# 119 Episode: Finished after 99 steps：10試行の平均step数 = 124.8
# 120 Episode: Finished after 108 steps：10試行の平均step数 = 121.9
# 121 Episode: Finished after 136 steps：10試行の平均step数 = 120.9
# 122 Episode: Finished after 98 steps：10試行の平均step数 = 117.5
# 123 Episode: Finished after 93 steps：10試行の平均step数 = 118.1
# 124 Episode: Finished after 154 steps：10試行の平均step数 = 125.0
# 125 Episode: Finished after 87 steps：10試行の平均step数 = 123.3
# 126 Episode: Finished after 118 steps：10試行の平均step数 = 115.1
# 127 Episode: Finished after 111 steps：10試行の平均step数 = 111.5
# 128 Episode: Finished after 129 steps：10試行の平均step数 = 113.3
# 129 Episode: Finished after 167 steps：10試行の平均step数 = 120.1
# 130 Episode: Finished after 117 steps：10試行の平均step数 = 121.0
# 131 Episode: Finished after 135 steps：10試行の平均step数 = 120.9
# 132 Episode: Finished after 98 steps：10試行の平均step数 = 120.9
# 133 Episode: Finished after 110 steps：10試行の平均step数 = 122.6
# 134 Episode: Finished after 99 steps：10試行の平均step数 = 117.1
# 135 Episode: Finished after 118 steps：10試行の平均step数 = 120.2
# 136 Episode: Finished after 108 steps：10試行の平均step数 = 119.2
# 137 Episode: Finished after 128 steps：10試行の平均step数 = 120.9
# 138 Episode: Finished after 103 steps：10試行の平均step数 = 118.3
# 139 Episode: Finished after 175 steps：10試行の平均step数 = 119.1
# 140 Episode: Finished after 102 steps：10試行の平均step数 = 117.6
# 141 Episode: Finished after 101 steps：10試行の平均step数 = 114.2
# 142 Episode: Finished after 128 steps：10試行の平均step数 = 117.2
# 143 Episode: Finished after 97 steps：10試行の平均step数 = 115.9
# 144 Episode: Finished after 200 steps：10試行の平均step数 = 126.0
# 145 Episode: Finished after 161 steps：10試行の平均step数 = 130.3
# 146 Episode: Finished after 137 steps：10試行の平均step数 = 133.2
# 147 Episode: Finished after 119 steps：10試行の平均step数 = 132.3
# 148 Episode: Finished after 99 steps：10試行の平均step数 = 131.9
# 149 Episode: Finished after 110 steps：10試行の平均step数 = 125.4
# 150 Episode: Finished after 116 steps：10試行の平均step数 = 126.8
# 151 Episode: Finished after 102 steps：10試行の平均step数 = 126.9
# 152 Episode: Finished after 123 steps：10試行の平均step数 = 126.4
# 153 Episode: Finished after 105 steps：10試行の平均step数 = 127.2
# 154 Episode: Finished after 109 steps：10試行の平均step数 = 118.1
# 155 Episode: Finished after 108 steps：10試行の平均step数 = 112.8
# 156 Episode: Finished after 105 steps：10試行の平均step数 = 109.6
# 157 Episode: Finished after 145 steps：10試行の平均step数 = 112.2
# 158 Episode: Finished after 117 steps：10試行の平均step数 = 114.0
# 159 Episode: Finished after 93 steps：10試行の平均step数 = 112.3
# 160 Episode: Finished after 117 steps：10試行の平均step数 = 112.4
# 161 Episode: Finished after 111 steps：10試行の平均step数 = 113.3
# 162 Episode: Finished after 132 steps：10試行の平均step数 = 114.2
# 163 Episode: Finished after 128 steps：10試行の平均step数 = 116.5
# 164 Episode: Finished after 155 steps：10試行の平均step数 = 121.1
# 165 Episode: Finished after 96 steps：10試行の平均step数 = 119.9
# 166 Episode: Finished after 112 steps：10試行の平均step数 = 120.6
# 167 Episode: Finished after 100 steps：10試行の平均step数 = 116.1
# 168 Episode: Finished after 113 steps：10試行の平均step数 = 115.7
# 169 Episode: Finished after 128 steps：10試行の平均step数 = 119.2
# 170 Episode: Finished after 95 steps：10試行の平均step数 = 117.0
# 171 Episode: Finished after 116 steps：10試行の平均step数 = 117.5
# 172 Episode: Finished after 121 steps：10試行の平均step数 = 116.4
# 173 Episode: Finished after 183 steps：10試行の平均step数 = 121.9
# 174 Episode: Finished after 118 steps：10試行の平均step数 = 118.2
# 175 Episode: Finished after 175 steps：10試行の平均step数 = 126.1
# 176 Episode: Finished after 102 steps：10試行の平均step数 = 125.1
# 177 Episode: Finished after 101 steps：10試行の平均step数 = 125.2
# 178 Episode: Finished after 137 steps：10試行の平均step数 = 127.6
# 179 Episode: Finished after 158 steps：10試行の平均step数 = 130.6
# 180 Episode: Finished after 174 steps：10試行の平均step数 = 138.5
# 181 Episode: Finished after 123 steps：10試行の平均step数 = 139.2
# 182 Episode: Finished after 116 steps：10試行の平均step数 = 138.7
# 183 Episode: Finished after 200 steps：10試行の平均step数 = 140.4
# 184 Episode: Finished after 189 steps：10試行の平均step数 = 147.5
# 185 Episode: Finished after 200 steps：10試行の平均step数 = 150.0
# 186 Episode: Finished after 200 steps：10試行の平均step数 = 159.8
# 187 Episode: Finished after 170 steps：10試行の平均step数 = 166.7
# 188 Episode: Finished after 150 steps：10試行の平均step数 = 168.0
# 189 Episode: Finished after 138 steps：10試行の平均step数 = 166.0
# 190 Episode: Finished after 100 steps：10試行の平均step数 = 158.6
# 191 Episode: Finished after 152 steps：10試行の平均step数 = 161.5
# 192 Episode: Finished after 167 steps：10試行の平均step数 = 166.6
# 193 Episode: Finished after 133 steps：10試行の平均step数 = 159.9
# 194 Episode: Finished after 108 steps：10試行の平均step数 = 151.8
# 195 Episode: Finished after 128 steps：10試行の平均step数 = 144.6
# 196 Episode: Finished after 126 steps：10試行の平均step数 = 137.2
# 197 Episode: Finished after 188 steps：10試行の平均step数 = 139.0
# 198 Episode: Finished after 160 steps：10試行の平均step数 = 140.0
# 199 Episode: Finished after 176 steps：10試行の平均step数 = 143.8
# 200 Episode: Finished after 170 steps：10試行の平均step数 = 150.8
# 201 Episode: Finished after 184 steps：10試行の平均step数 = 154.0
# 202 Episode: Finished after 188 steps：10試行の平均step数 = 156.1
# 203 Episode: Finished after 193 steps：10試行の平均step数 = 162.1
# 204 Episode: Finished after 189 steps：10試行の平均step数 = 170.2
# 205 Episode: Finished after 200 steps：10試行の平均step数 = 177.4
# 206 Episode: Finished after 200 steps：10試行の平均step数 = 184.8
# 207 Episode: Finished after 200 steps：10試行の平均step数 = 186.0
# 208 Episode: Finished after 200 steps：10試行の平均step数 = 190.0
# 209 Episode: Finished after 200 steps：10試行の平均step数 = 192.4
# 210 Episode: Finished after 200 steps：10試行の平均step数 = 195.4
# 211 Episode: Finished after 200 steps：10試行の平均step数 = 197.0
# 212 Episode: Finished after 200 steps：10試行の平均step数 = 198.2
# 213 Episode: Finished after 200 steps：10試行の平均step数 = 198.9
# 214 Episode: Finished after 200 steps：10試行の平均step数 = 200.0
# 10回連続成功
# 215 Episode: Finished after 200 steps：10試行の平均step数 = 200.0
